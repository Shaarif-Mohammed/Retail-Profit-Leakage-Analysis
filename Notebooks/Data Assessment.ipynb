# %% [markdown]
# ## Retail Profit Leakage & Discount Effectiveness Analysis
#
# ### Notebook Purpose: Perform data profiling and quality assessment on the Sample Superstore dataset prior to dimensional modeling and SQL implementation.

# %%
import pandas as pd

# %% [markdown]
# #### Data Loading

# %%
df = pd.read_csv("C:\\Users\\SHAARIF ANAS\\Desktop\\Projects\\Profit Leakage and Discount Profitability Analysis\\Superstore Dataset.csv")
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800   1/3/2023   1/7/2023  Standard Class    DP-13000
# 1       2  US-2023-112326   1/4/2023   1/8/2023  Standard Class    PO-19195
# 2       3  US-2023-112326   1/4/2023   1/8/2023  Standard Class    PO-19195
# 3       4  US-2023-112326   1/4/2023   1/8/2023  Standard Class    PO-19195
# 4       5  US-2023-141817   1/5/2023  1/12/2023  Standard Class    MB-18085
#
#    Customer Name      Segment Country/Region          City  ... Postal Code  \
# 0  Darren Powers     Consumer  United States       Houston  ...       77095
# 1  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 2  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 3  Phillina Ober  Home Office  United States    Naperville  ...       60540
# 4     Mick Brown     Consumer  United States  Philadelphia  ...       19143
#
# ...

# %% [markdown]
# #### Dataset Structure

# %%
print("Number of Rows :", df.shape[0])
print("Number of Columns :", df.shape[1])
print("Column Data Types")
print(df.dtypes)
# Out:
# Number of Rows : 10194
# Number of Columns : 21
# Column Data Types
# Row ID              int64
# Order ID           object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Customer ID        object
# Customer Name      object
# Segment            object
# Country/Region     object
# City               object
# State/Province     object
# Postal Code        object
# Region             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# dtype: object

# %% [markdown]
# #### Missing Value and Duplicate records Assessment

# %%
print("Missing Values :")
print(df.isnull().sum())
print("Duplicate records:")
print(df.duplicated().sum())
# Out:
# Missing Values :
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country/Region    0
# City              0
# State/Province    0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dtype: int64
# Duplicate records:
# 0

# %% [markdown]
# #### Numerical Profiling

# %%
print("Numerical Summary")
print(df.describe())
# Out:
# Numerical Summary
#              Row ID         Sales      Quantity      Discount        Profit
# count  10194.000000  10194.000000  10194.000000  10194.000000  10194.000000
# mean    5097.500000    228.225854      3.791838      0.155385     28.673417
# std     2942.898656    619.906839      2.228317      0.206249    232.465115
# min        1.000000      0.444000      1.000000      0.000000  -6599.978000
# 25%     2549.250000     17.220000      2.000000      0.000000      1.760800
# 50%     5097.500000     53.910000      3.000000      0.200000      8.690000
# 75%     7645.750000    209.500000      5.000000      0.200000     29.297925
# max    10194.000000  22638.480000     14.000000      0.800000   8399.976000

# %% [markdown]
# #### Cardinality Analysis

# %%
print("Ctegorical Summary")
print(df.describe(include= 'object'))
# Out:
# Ctegorical Summary
#               Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# count            10194      10194       10194           10194       10194
# unique            5111       1242        1338               4         804
# top     US-2026-100111   9/5/2025  12/16/2024  Standard Class    WB-21850
# freq                14         38          38            6120          41
#
#         Customer Name   Segment Country/Region           City State/Province  \
# count           10194     10194          10194          10194          10194
# unique            800         3              2            542             59
# top     William Brown  Consumer  United States  New York City     California
# freq               41      5281           9994            915           2001
#
#        Postal Code Region       Product ID         Category Sub-Category  \
# count        10194  10194            10194            10194        10194
# ...

# %% [markdown]
# #### Unique Values of low Cardinality Columns

# %%
selected_cols = [
    'Country/Region',
    'Region',
    'Segment',
    'Category',
    'Sub-Category',
    'Ship Mode'
]

for col in selected_cols:
    print(f"\n{'='*50}")
    print(f"{col}")
    print(f"{'='*50}")

    unique_vals = sorted(df[col].dropna().unique())

    print(f"Unique Count: {len(unique_vals)}")
    print("Values:")
    print(unique_vals)
# Out:
# ...
# Country/Region
# ...
# Unique Count: 2
# Values:
# ['Canada', 'United States']
#
# ...
# Region
# ...
# Unique Count: 4
# Values:
# ['Central', 'East', 'South', 'West']
#
# ...
# Segment
# ...
# Unique Count: 3
# Values:
# ['Consumer', 'Corporate', 'Home Office']
#
# ...
# Category
# ...
# Unique Count: 3
# Values:
# ['Furniture', 'Office Supplies', 'Technology']
#
# ...
# Sub-Category
# ...
# Unique Count: 17
# Values:
# ['Accessories', 'Appliances', 'Art', 'Binders', 'Bookcases', 'Chairs', 'Copiers', 'Envelopes', 'Fasteners', 'Furnishings', 'Labels', 'Machines', 'Paper', 'Phones', 'Storage', 'Supplies', 'Tables']
#
# ...
# Ship Mode
# ...
# Unique Count: 4
# Values:
# ['First Class', 'Same Day', 'Second Class', 'Standard Class']
